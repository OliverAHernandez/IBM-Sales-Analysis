# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score,roc_auc_score,f1_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression,PassiveAggressiveClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier,GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
sns.set(style='darkgrid')

# %%
data = pd.read_csv('../data/clean_data.csv')
data.head()
# Out:
#    y_hat  Category_Car Electronics  Category_Performance & Non-auto  \
# 0      1                         0                                0
# 1      0                         0                                0
# 2      1                         0                                1
# 3      0                         0                                1
# 4      0                         0                                0
#
#    Category_Tires & Wheels  Region_Midwest  Region_Northeast  \
# 0                        0               0                 0
# 1                        0               0                 0
# 2                        0               0                 0
# 3                        0               1                 0
# 4                        0               0                 0
#
#    Region_Northwest  Region_Pacific  Region_Southeast  Region_Southwest  ...  \
# 0                 1               0                 0                 0  ...
# ...

# %%
X = data.drop(columns='y_hat')

# %%
y = data['y_hat']

# %%
X1 = poly.fit_transform(X)

# %%
df = pd.DataFrame(X1, columns=poly.get_feature_names(list(X.columns)))

# %%
df['y_hat'] = y

# %%
X = df.drop(columns='y_hat')

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42)

# %% [markdown]
# ## Modeling

# %%
logreg_class = LogisticRegression()
logreg_class.fit(X_train, y_train)
# Out:
# C:\Users\oaher\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
def accuracy_score_eval(model,train, test):
    return accuracy_score(test,model.predict(train))

# %%
def roc_auc_score_eval(model,train, test):
    return roc_auc_score(test,model.predict(train))

# %%
def f1_eval(model,train, test):
    return f1_score(test,model.predict(train))

# %%
print(f'logreg_class-train = {f1_eval(logreg_class, X_train, y_train)}', f'logreg_class-test = {f1_eval(logreg_class, X_test, y_test)}')
# Out:
# logreg_class-train = 0.5133060388945753 logreg_class-test = 0.4503770739064856

# %%
print(f'logreg_class-train = {accuracy_score_eval(logreg_class, X_train, y_train)}', f'logreg_class-test = {accuracy_score_eval(logreg_class, X_test, y_test)}')
# Out:
# logreg_class-train = 0.8373719582057904 logreg_class-test = 0.8130610988559996

# %%
print(f'logreg_class-train = {roc_auc_score_eval(logreg_class, X_train, y_train)}', f'logreg_class-test = {roc_auc_score_eval(logreg_class, X_test, y_test)}')
# Out:
# logreg_class-train = 0.6755092470505661 logreg_class-test = 0.6449302646616505

# %%
logreg_class.coef_
# Out:
# array([[-0.02753904, -0.15169173, -0.15568595, ...,  0.00092616,
#          0.00092616,  0.23447091]])

# %%
coeficient = {X.columns[i]:[logreg_class.coef_[0][i]] for i in range(len(X.columns))}

# %%
coeficient = pd.DataFrame(coeficient, index=['Coeficient']).T.sort_values('Coeficient')

# %%
coeficient = coeficient.sort_values(['Coeficient'],ascending=False)

# %%
coeficient.head(50)
# Out:
#                                                     Coeficient
# Competitor_None Client Size By Employee Count_3...    1.485763
# Region_Southeast Competitor_Unknown Revenue Fro...    1.370363
# Region_Northwest Revenue From Client Past Two Y...    1.364733
# Region_Northwest Client Size By Revenue_3 Clien...    1.279442
# Region_Pacific Client Size By Revenue_3 Opportu...    1.213043
# Region_Southeast Client Size By Revenue_2 Clien...    1.174065
# Region_Midwest POS_Reseller Opportunity Amount ...    1.171777
# POS_Reseller Competitor_None Client Size By Emp...    1.170683
# Category_Performance & Non-auto Client Size By ...    1.167787
# Competitor_Unknown Client Size By Employee Coun...    1.159493
# Region_Pacific POS_Reseller Revenue From Client...    1.150841
# Region_Midwest Revenue From Client Past Two Yea...    1.141131
# Region_Pacific POS_Reseller Opportunity Amount ...    1.139401
# Region_Pacific Competitor_None Client Size By E...    1.128128
# ...
